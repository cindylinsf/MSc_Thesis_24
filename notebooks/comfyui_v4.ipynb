# %% [markdown]
# # Offspring Generation with ComfyUI - Version 4.0
#
# Were getting very similar generated photos in earlier results despite randomizing parameters and changing the prompt to be less specific. Now testing blend ratios of source files (generated donor photos and mine).
#
# The scenarios include:
# - Random ratio (0.2-0.8)
# - Donor dominant (80%)
# - Balanced (50/50)
# - Me dominant (80%)
#
# Goal 🤞🏼: 85 donor profiles with 4 scenarios each (340 total generations)
#
# - This one failed because it blended mine and the donor's photos, but not generating offspring
#
# ---

# %% [markdown]
# ## 1. Setup and Imports

# %%
# Basic imports
import sys
import os
from pathlib import Path
import json
import csv
from datetime import datetime
import random
import logging
import shutil
import time
from typing import Dict, List, Tuple, Optional

# %%
# Server-related imports
import subprocess
import webbrowser
from time import sleep

# %%
# Configure logging
# Re-run this cell if logging needs to be restarted
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s'
)

# %% [markdown]
# ## 2. Configuration and Constants

# %%
# Base paths
COMFY_BASE = Path("/Users/cindylinsf/Documents/CCI/THESIS/Msc_Thesis_Project_Files/models/ComfyUI")

# %%
PATHS = {
    'output': COMFY_BASE / "output",
    'workflows': COMFY_BASE / "output/workflows",
    'logs': COMFY_BASE / "output/logs",
    'donors': Path("/Users/cindylinsf/Documents/CCI/THESIS/Msc_Thesis_Project_Files/data/input/comfyui_source_files"),
    'my_photo': Path("/Users/cindylinsf/Documents/CCI/THESIS/Msc_Thesis_Project_Files/data/input/cindy.jpg")
}

BASE_WORKFLOW_PATH = PATHS['workflows'] / "base_workflow_comfyui4.json"

# %%
# Blend scenarios and naming
BLEND_SCENARIOS = {
    'random': (0.2, 0.8),
    'donor_dominant': 0.8,
    'balanced': 0.5,
    'me_dominant': 0.8
}

OUTPUT_NAMING = {
    'random': 'rand{ratio}',
    'donor_dominant': 'donor80',
    'balanced': 'blend50',
    'me_dominant': 'me80'
}

# %%
# Prompt variations for more diverse results
PROMPT_VARIATIONS = {
    'age_range': (10, 14),  # months
    'expressions': [
        'candid', 'curious', 'happy', 'neutral', 
        'gentle smile', 'attentive', 'peaceful'
    ],
    'lighting_conditions': [
        'natural daylight', 'soft studio lighting', 
        'gentle window light', 'professional portrait lighting'
    ]
}

# Model parameters
MODEL_PARAMS = {
    'denoise_strength': (0.4, 0.7),
    'cfg_scale': (4, 7),
    'ip_adapter_strength': (0.6, 0.8),
    'controlnet_strength': (0.6, 0.8)
}

# %%
base_workflow_json = {
    "last_node_id": 8,
    "last_link_id": 12,
    "nodes": [
        {
            "id": 1,
            "type": "LoadImage",
            "pos": [
                50,
                200
            ],
            "size": [
                315,
                98
            ],
            "flags": {},
            "order": 0,
            "mode": 0,
            "outputs": [
                {
                    "name": "IMAGE",
                    "type": "IMAGE",
                    "links": [3],
                    "slot_index": 0
                }
            ],
            "properties": {
                "Node name for S&R": "LoadImage"
            }
        },
        {
            "id": 2,
            "type": "LoadImage",
            "pos": [
                50,
                400
            ],
            "size": [
                315,
                98
            ],
            "flags": {},
            "order": 1,
            "mode": 0,
            "outputs": [
                {
                    "name": "IMAGE",
                    "type": "IMAGE",
                    "links": [4],
                    "slot_index": 0
                }
            ],
            "properties": {
                "Node name for S&R": "LoadImage"
            }
        },
        {
            "id": 3,
            "type": "VAEEncode",
            "pos": [
                400,
                200
            ],
            "size": [
                210,
                46
            ],
            "flags": {},
            "order": 2,
            "mode": 0,
            "inputs": [
                {
                    "name": "pixels",
                    "type": "IMAGE",
                    "link": 3
                }
            ],
            "outputs": [
                {
                    "name": "LATENT",
                    "type": "LATENT",
                    "links": [5],
                    "slot_index": 0
                }
            ]
        },
        {
            "id": 4,
            "type": "VAEEncode",
            "pos": [
                400,
                400
            ],
            "size": [
                210,
                46
            ],
            "flags": {},
            "order": 3,
            "mode": 0,
            "inputs": [
                {
                    "name": "pixels",
                    "type": "IMAGE",
                    "link": 4
                }
            ],
            "outputs": [
                {
                    "name": "LATENT",
                    "type": "LATENT",
                    "links": [6],
                    "slot_index": 0
                }
            ]
        },
        {
            "id": 5,
            "type": "LatentBlend",
            "pos": [
                650,
                300
            ],
            "size": [
                210,
                82
            ],
            "flags": {},
            "order": 4,
            "mode": 0,
            "inputs": [
                {
                    "name": "samples1",
                    "type": "LATENT",
                    "link": 5
                },
                {
                    "name": "samples2",
                    "type": "LATENT",
                    "link": 6
                }
            ],
            "outputs": [
                {
                    "name": "LATENT",
                    "type": "LATENT",
                    "links": [7],
                    "slot_index": 0
                }
            ],
            "properties": {
                "Node name for S&R": "LatentBlend"
            },
            "widgets_values": [
                0.5
            ]
        },
        {
            "id": 6,
            "type": "VAEDecode",
            "pos": [
                900,
                300
            ],
            "size": [
                210,
                46
            ],
            "flags": {},
            "order": 5,
            "mode": 0,
            "inputs": [
                {
                    "name": "samples",
                    "type": "LATENT",
                    "link": 7
                }
            ],
            "outputs": [
                {
                    "name": "IMAGE",
                    "type": "IMAGE",
                    "links": [8],
                    "slot_index": 0
                }
            ]
        },
        {
            "id": 7,
            "type": "SaveImage",
            "pos": [
                1150,
                300
            ],
            "size": [
                210,
                270
            ],
            "flags": {},
            "order": 6,
            "mode": 0,
            "inputs": [
                {
                    "name": "images",
                    "type": "IMAGE",
                    "link": 8
                }
            ],
            "properties": {},
            "widgets_values": [
                "ComfyUI"
            ]
        }
    ],
    "links": [
        [3, 1, 0, 3, 0, "IMAGE"],
        [4, 2, 0, 4, 0, "IMAGE"],
        [5, 3, 0, 5, 0, "LATENT"],
        [6, 4, 0, 5, 1, "LATENT"],
        [7, 5, 0, 6, 0, "LATENT"],
        [8, 6, 0, 7, 0, "IMAGE"]
    ],
    "groups": [],
    "config": {},
    "extra": {},
    "version": 0.4
}

# %% [markdown]
# ## 3. Utility Functions

# %%
def setup_directories() -> None:
    """Create necessary directories and verify paths."""
    try:
        for name, path in PATHS.items():
            if name != 'my_photo':
                path.mkdir(parents=True, exist_ok=True)
                logging.info(f"Created/verified directory: {path}")
        
        # Verify my_photo exists
        if not PATHS['my_photo'].exists():
            raise FileNotFoundError(f"My photo not found at: {PATHS['my_photo']}")
        
        # Create base workflow if it doesn't exist
        if not BASE_WORKFLOW_PATH.exists():
            with open(BASE_WORKFLOW_PATH, 'w') as f:
                json.dump(base_workflow_json, f, indent=2)
            logging.info(f"Created base workflow at: {BASE_WORKFLOW_PATH}")
            
    except Exception as e:
        logging.error(f"Error in directory setup: {str(e)}")
        raise

# %%
def generate_random_prompt() -> str:
    """Generate a randomized prompt with variations.
    Each prompt will have random age, expression, and lighting."""
    age = random.randint(*PROMPT_VARIATIONS['age_range'])
    expression = random.choice(PROMPT_VARIATIONS['expressions'])
    lighting = random.choice(PROMPT_VARIATIONS['lighting_conditions'])
    
    return (
        f"portrait of a {age} month old baby with distinctive facial features, "
        f"{expression} expression, detailed facial features, {lighting}, "
        f"high quality photograph, photorealistic"
    )

def get_random_parameters() -> Dict:
    """Generate random parameters within defined ranges.
    Creates a complete set of parameters for ComfyUI workflow."""
    return {
        'denoise_strength': random.uniform(*MODEL_PARAMS['denoise_strength']),
        'cfg_scale': random.uniform(*MODEL_PARAMS['cfg_scale']),
        'ip_adapter_strength': random.uniform(*MODEL_PARAMS['ip_adapter_strength']),
        'controlnet_strength': random.uniform(*MODEL_PARAMS['controlnet_strength']),
        'seed': random.randint(1, 2**32 - 1)
    }

def get_blend_ratio(scenario: str) -> float:
    """Get blend ratio based on scenario.
    For random scenario, generates a ratio between 0.2-0.8.
    For other scenarios, uses predefined values."""
    if scenario == 'random':
        return round(random.uniform(*BLEND_SCENARIOS[scenario]), 2)
    return BLEND_SCENARIOS[scenario]

# %% [markdown]
# ## 4. Logging Functions

# %%
class GenerationLogger:
    """Handles logging of generation parameters and results.
    Creates two types of logs:
    1. CSV log for quick overview
    2. Detailed JSON logs for each generation"""
    
    def __init__(self, log_dir: Path):
        self.log_dir = log_dir
        self.csv_path = log_dir / 'generation_log.csv'
        self.json_dir = log_dir / 'detailed_logs'
        self.json_dir.mkdir(parents=True, exist_ok=True)
        
        # Initialize CSV if it doesn't exist
        if not self.csv_path.exists():
            self._initialize_csv()
    
    def _initialize_csv(self):
        headers = [
            'timestamp', 'donor_id', 'scenario', 'blend_ratio',
            'seed', 'denoise_strength', 'cfg_scale',
            'ip_adapter_strength', 'controlnet_strength',
            'output_filename', 'prompt'
        ]
        with open(self.csv_path, 'w', newline='') as f:
            writer = csv.writer(f)
            writer.writerow(headers)
    
    def log_generation(self, 
                      donor_id: str,
                      scenario: str,
                      parameters: Dict,
                      output_filename: str,
                      prompt: str):
        """Log a single generation to both CSV and JSON.
        Creates both a CSV entry and a detailed JSON log file."""
        timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
        
        # CSV logging
        csv_row = [
            timestamp, donor_id, scenario, parameters['blend_ratio'],
            parameters['seed'], parameters['denoise_strength'],
            parameters['cfg_scale'], parameters['ip_adapter_strength'],
            parameters['controlnet_strength'], output_filename, prompt
        ]
        
        with open(self.csv_path, 'a', newline='') as f:
            writer = csv.writer(f)
            writer.writerow(csv_row)
        
        # Detailed JSON logging
        json_log = {
            'timestamp': timestamp,
            'donor_id': donor_id,
            'scenario': scenario,
            'parameters': parameters,
            'output_filename': output_filename,
            'prompt': prompt
        }
        
        json_path = self.json_dir / f"{donor_id}_{timestamp}.json"
        with open(json_path, 'w') as f:
            json.dump(json_log, f, indent=2)

# %%
class WorkflowTracker:
    """Tracks the progress of workflow processing.
    Keeps track of which workflows have been processed and any notes/errors."""
    
    def __init__(self, tracker_dir: Path):
        self.tracker_dir = tracker_dir
        self.tracker_file = tracker_dir / 'processed_workflows.csv'
        self._initialize_tracker()
        
    def _initialize_tracker(self):
        """Initialize tracker file if it doesn't exist."""
        if not self.tracker_file.exists():
            with open(self.tracker_file, 'w', newline='') as f:
                writer = csv.writer(f)
                writer.writerow(['workflow_file', 'donor_id', 'scenario', 'timestamp', 'processed', 'notes'])
    
    def add_workflow(self, workflow_file: str, donor_id: str, scenario: str):
        """Add new workflow to tracking."""
        with open(self.tracker_file, 'a', newline='') as f:
            writer = csv.writer(f)
            writer.writerow([
                workflow_file,
                donor_id,
                scenario,
                datetime.now().strftime('%Y%m%d_%H%M%S'),
                'No',
                ''
            ])
    
    def mark_processed(self, workflow_file: str, notes: str = ''):
        """Mark workflow as processed and add any notes about the result."""
        # Read existing data
        with open(self.tracker_file, 'r', newline='') as f:
            reader = csv.reader(f)
            data = list(reader)
            header = data[0]
            rows = data[1:]
        
        # Update processed status
        for row in rows:
            if row[0] == workflow_file:
                row[4] = 'Yes'
                row[5] = notes
        
        # Write back
        with open(self.tracker_file, 'w', newline='') as f:
            writer = csv.writer(f)
            writer.writerow(header)
            writer.writerows(rows)
    
    def get_unprocessed(self) -> List[str]:
        """Get list of unprocessed workflows."""
        unprocessed = []
        with open(self.tracker_file, 'r', newline='') as f:
            reader = csv.reader(f)
            next(reader)  # Skip header
            for row in reader:
                if row[4] == 'No':
                    unprocessed.append(row[0])
        return unprocessed

# %% [markdown]
# ## 5. Workflow Management

# %%
class WorkflowManager:
    def __init__(self, base_workflow_path: Path):
        self.base_workflow_path = base_workflow_path
        self.load_base_workflow()
    
    def load_base_workflow(self):
        """Load the base workflow JSON."""
        try:
            with open(self.base_workflow_path, 'r') as f:
                self.base_workflow = json.load(f)
            logging.info("Base workflow loaded successfully")
        except Exception as e:
            logging.error(f"Error loading base workflow: {str(e)}")
            raise
    
    def create_variation_workflow(self,
                               my_photo_path: Path,
                               donor_photo_path: Path,
                               parameters: Dict,
                               output_filename: str) -> Dict:
        """Create a workflow variation with specified parameters."""
        workflow = self.base_workflow.copy()
        
        # Update LoadImage nodes
        for node in workflow['nodes']:
            if node['type'] == 'LoadImage':
                if node['id'] == 1:  # Your photo
                    node['widgets_values'] = [str(my_photo_path)]
                elif node['id'] == 2:  # Donor photo
                    node['widgets_values'] = [str(donor_photo_path)]
            
            # Update LatentBlend node parameters
            elif node['type'] == 'LatentBlend':
                node['widgets_values'] = [parameters['blend_ratio']]
            
            # Update SaveImage node
            elif node['type'] == 'SaveImage':
                node['widgets_values'] = [output_filename]
        
        return workflow
    
    def verify_workflow_structure(self):
        """Verify that workflow has all required nodes."""
        required_nodes = {
            'LoadImage': 2,  # Need two of these
            'VAEEncode': 2,
            'LatentBlend': 1,
            'VAEDecode': 1,
            'SaveImage': 1
        }
        
        node_counts = {}
        for node in self.base_workflow['nodes']:
            node_type = node['type']
            node_counts[node_type] = node_counts.get(node_type, 0) + 1
        
        for node_type, required_count in required_nodes.items():
            actual_count = node_counts.get(node_type, 0)
            if actual_count < required_count:
                raise ValueError(
                    f"Workflow missing required nodes. Need {required_count} {node_type}, "
                    f"found {actual_count}"
                )

# %% [markdown]
# ## 6. Main Processing

# %%
# Create base workflow
def create_base_workflow():
    """Create the base workflow JSON file."""
    base_workflow = {
    "last_node_id": 9,
    "last_link_id": 0,
    "nodes": [
        {
            "id": 1,
            "type": "LoadImage",
            "pos": [
                50,
                200
            ],
            "size": [
                315,
                102
            ],
            "outputs": [
                {
                    "name": "IMAGE",
                    "type": "IMAGE",
                    "links": [
                        5
                    ],
                    "slot_index": 0
                }
            ]
        },
        {
            "id": 2,
            "type": "LoadImage",
            "pos": [
                50,
                400
            ],
            "size": [
                315,
                102
            ],
            "outputs": [
                {
                    "name": "IMAGE",
                    "type": "IMAGE",
                    "links": [
                        6
                    ],
                    "slot_index": 0
                }
            ]
        },
        # ... rest of your workflow nodes
    ],
    "links": [
        [
            5,
            1,
            0,
            5,
            0,
            "IMAGE"
        ],
        [
            6,
            2,
            0,
            5,
            1,
            "IMAGE"
        ],
        [
            7,
            3,
            0,
            5,
            0,
            "MODEL"
        ],
        [
            8,
            3,
            1,
            4,
            0,
            "CLIP"
        ]
    ],
    "config": {},
    "extra": {
        "ds": {
            "scale": 1.5,
            "offset": [
                -1350,
                -211
            ]
        }
    }
}

    # Create workflows directory if it doesn't exist
    workflow_dir = PATHS['workflows']
    workflow_dir.mkdir(parents=True, exist_ok=True)
    
    # Save the base workflow
    workflow_path = workflow_dir / "base_workflow.json"
    with open(workflow_path, 'w') as f:
        json.dump(base_workflow, f, indent=2)
    
    logging.info(f"Created base workflow at: {workflow_path}")
    return workflow_path

# %%
def process_donor_batch():
    """Process a batch of donors with different scenarios."""
    try:
        # Initialize components
        setup_directories()
        logger = GenerationLogger(PATHS['logs'])
        workflow_manager = WorkflowManager(PATHS['workflows'] / "base_workflow_comfyui4.json")
        tracker = WorkflowTracker(PATHS['logs'])  # Initialize tracker here
        
        # Get donor files
        donor_files = sorted(list(PATHS['donors'].glob("*.jpeg")))
        logging.info(f"Found {len(donor_files)} donor files to process")
        
        # Process each donor
        for donor_idx, donor_path in enumerate(donor_files, 1):
            donor_id = donor_path.stem
            logging.info(f"\nProcessing donor {donor_idx}/{len(donor_files)}: {donor_id}")
            
            # Process each scenario
            for scenario in BLEND_SCENARIOS.keys():
                try:
                    # Get parameters
                    parameters = get_random_parameters()
                    parameters['blend_ratio'] = get_blend_ratio(scenario)
                    prompt = generate_random_prompt()
                    
                    # Generate output filename
                    suffix = OUTPUT_NAMING[scenario]
                    if scenario == 'random':
                        suffix = suffix.format(ratio=int(parameters['blend_ratio'] * 100))
                    output_filename = f"{donor_id}_{suffix}.png"
                    
                    # Create and save workflow
                    workflow = workflow_manager.create_variation_workflow(
                        PATHS['my_photo'],
                        donor_path,
                        parameters,
                        output_filename
                    )
                    
                    # Save workflow and add to tracker
                    workflow_file = f"{donor_id}_{suffix}.json"
                    workflow_path = PATHS['workflows'] / workflow_file
                    
                    with open(workflow_path, 'w') as f:
                        json.dump(workflow, f, indent=2)
                    
                    # Add to tracker
                    tracker.add_workflow(workflow_file, donor_id, scenario)
                    
                    # Log generation
                    logger.log_generation(
                        donor_id=donor_id,
                        scenario=scenario,
                        parameters=parameters,
                        output_filename=output_filename,
                        prompt=prompt
                    )
                    
                    logging.info(f"✓ Created workflow for {scenario} scenario: {output_filename}")
                    
                except Exception as e:
                    logging.error(f"Error processing {donor_id} - {scenario}: {str(e)}")
                    continue
            
            # Periodic save point
            if donor_idx % 10 == 0:
                logging.info(f"Completed {donor_idx}/{len(donor_files)} donors")
                
            time.sleep(1)  # Brief pause between donors
            
    except Exception as e:
        logging.error(f"Batch processing error: {str(e)}")
        raise
    
    logging.info("Batch processing completed!")

# %% [markdown]
# ## 7. Server Management and Execution

# %%
def start_comfyui_server():
    """Start ComfyUI server and open browser interface.
    IMPORTANT: Keep this notebook running while using ComfyUI"""
    try:
        server_process = subprocess.Popen(
            ['python', str(COMFY_BASE / 'main.py'), '--listen', '0.0.0.0', '--port', '8188'],
            stdout=subprocess.PIPE,
            stderr=subprocess.PIPE
        )

        # Wait for server to start
        sleep(5)

        # Open the UI in default browser
        webbrowser.open('http://localhost:8188')
        
        print("ComfyUI server started! The interface should open in your browser.")
        print("Keep this notebook running while you use ComfyUI.")
        
        return server_process
    except Exception as e:
        logging.error(f"Failed to start ComfyUI server: {str(e)}")
        raise

def check_progress():
    """Check which workflows still need processing.
    Run this function to see remaining workflows."""
    tracker = WorkflowTracker(PATHS['logs'])
    unprocessed = tracker.get_unprocessed()
    
    print(f"Unprocessed workflows: {len(unprocessed)}")
    for workflow in unprocessed:
        print(f"- {workflow}")
        
    return unprocessed

# Expected output: Server startup messages
# Common errors:
# - Port already in use: ComfyUI already running
# - Permission denied: Check Python permissions

# %% [markdown]
# ### Execution Steps

# %%
# Step 1: Start ComfyUI server
server = start_comfyui_server()
# Out:
# ComfyUI server started! The interface should open in your browser.
# Keep this notebook running while you use ComfyUI.

# %%
# Step 2: Create base workflow
base_workflow_path = create_base_workflow()
# Out:
# 2024-11-22 20:18:53,561 - INFO - Created base workflow at: /Users/cindylinsf/Documents/CCI/THESIS/Msc_Thesis_Project_Files/models/ComfyUI/output/workflows/base_workflow.json

# %%
# Step 3: Generate all workflows
process_donor_batch()
# Out:
# 2024-11-22 20:18:56,220 - INFO - Created/verified directory: /Users/cindylinsf/Documents/CCI/THESIS/Msc_Thesis_Project_Files/models/ComfyUI/output
# 2024-11-22 20:18:56,220 - INFO - Created/verified directory: /Users/cindylinsf/Documents/CCI/THESIS/Msc_Thesis_Project_Files/models/ComfyUI/output/workflows
# 2024-11-22 20:18:56,221 - INFO - Created/verified directory: /Users/cindylinsf/Documents/CCI/THESIS/Msc_Thesis_Project_Files/models/ComfyUI/output/logs
# 2024-11-22 20:18:56,222 - INFO - Created/verified directory: /Users/cindylinsf/Documents/CCI/THESIS/Msc_Thesis_Project_Files/data/input/comfyui_source_files
# 2024-11-22 20:18:56,223 - INFO - Base workflow loaded successfully
# 2024-11-22 20:18:56,224 - INFO - Found 84 donor files to process
# 2024-11-22 20:18:56,224 - INFO -
# Processing donor 1/84: aug_cla_2_gem_wo
# 2024-11-22 20:18:56,227 - INFO - ✓ Created workflow for random scenario: aug_cla_2_gem_wo_rand36.png
# 2024-11-22 20:18:56,228 - INFO - ✓ Created workflow for donor_dominant scenario: aug_cla_2_gem_wo_donor80.png
# 2024-11-22 20:18:56,230 - INFO - ✓ Created workflow for balanced scenario: aug_cla_2_gem_wo_blend50.png
# 2024-11-22 20:18:56,232 - INFO - ✓ Created workflow for me_dominant scenario: aug_cla_2_gem_wo_me80.png
# 2024-11-22 20:18:57,237 - INFO -
# Processing donor 2/84: aug_cla_3_gem_wo
# 2024-11-22 20:18:57,247 - INFO - ✓ Created workflow for random scenario: aug_cla_3_gem_wo_rand71.png
# 2024-11-22 20:18:57,253 - INFO - ✓ Created workflow for donor_dominant scenario: aug_cla_3_gem_wo_donor80.png
# 2024-11-22 20:18:57,260 - INFO - ✓ Created workflow for balanced scenario: aug_cla_3_gem_wo_blend50.png
# 2024-11-22 20:18:57,262 - INFO - ✓ Created workflow for me_dominant scenario: aug_cla_3_gem_wo_me80.png
# 2024-11-22 20:18:58,267 - INFO -
# Processing donor 3/84: aug_cla_4_gem_wo
# 2024-11-22 20:18:58,275 - INFO - ✓ Created workflow for random scenario: aug_cla_4_gem_wo_rand37.png
# 2024-11-22 20:18:58,282 - INFO - ✓ Created workflow for donor_dominant scenario: aug_cla_4_gem_wo_donor80.png
# 2024-11-22 20:18:58,288 - INFO - ✓ Created workflow for balanced scenario: aug_cla_4_gem_wo_blend50.png
# 2024-11-22 20:18:58,290 - INFO - ✓ Created workflow for me_dominant scenario: aug_cla_4_gem_wo_me80.png
# 2024-11-22 20:18:59,296 - INFO -
# Processing donor 4/84: aug_cla_5_gem_wo
# 2024-11-22 20:18:59,302 - INFO - ✓ Created workflow for random scenario: aug_cla_5_gem_wo_rand25.png
# 2024-11-22 20:18:59,304 - INFO - ✓ Created workflow for donor_dominant scenario: aug_cla_5_gem_wo_donor80.png
# 2024-11-22 20:18:59,307 - INFO - ✓ Created workflow for balanced scenario: aug_cla_5_gem_wo_blend50.png
# 2024-11-22 20:18:59,313 - INFO - ✓ Created workflow for me_dominant scenario: aug_cla_5_gem_wo_me80.png
# 2024-11-22 20:19:00,319 - INFO -
# Processing donor 5/84: aug_cla_6_gem_demo
# 2024-11-22 20:19:00,327 - INFO - ✓ Created workflow for random scenario: aug_cla_6_gem_demo_rand79.png
# 2024-11-22 20:19:00,330 - INFO - ✓ Created workflow for donor_dominant scenario: aug_cla_6_gem_demo_donor80.png
# 2024-11-22 20:19:00,333 - INFO - ✓ Created workflow for balanced scenario: aug_cla_6_gem_demo_blend50.png
# 2024-11-22 20:19:00,340 - INFO - ✓ Created workflow for me_dominant scenario: aug_cla_6_gem_demo_me80.png
# 2024-11-22 20:19:01,346 - INFO -
# Processing donor 6/84: aug_cla_6_gem_wo
# 2024-11-22 20:19:01,356 - INFO - ✓ Created workflow for random scenario: aug_cla_6_gem_wo_rand50.png
# 2024-11-22 20:19:01,363 - INFO - ✓ Created workflow for donor_dominant scenario: aug_cla_6_gem_wo_donor80.png
# 2024-11-22 20:19:01,365 - INFO - ✓ Created workflow for balanced scenario: aug_cla_6_gem_wo_blend50.png
# 2024-11-22 20:19:01,367 - INFO - ✓ Created workflow for me_dominant scenario: aug_cla_6_gem_wo_me80.png
# 2024-11-22 20:19:02,372 - INFO -
# Processing donor 7/84: aug_cla_7_gem_wo
# 2024-11-22 20:19:02,380 - INFO - ✓ Created workflow for random scenario: aug_cla_7_gem_wo_rand80.png
# 2024-11-22 20:19:02,385 - INFO - ✓ Created workflow for donor_dominant scenario: aug_cla_7_gem_wo_donor80.png
# 2024-11-22 20:19:02,392 - INFO - ✓ Created workflow for balanced scenario: aug_cla_7_gem_wo_blend50.png
# 2024-11-22 20:19:02,395 - INFO - ✓ Created workflow for me_dominant scenario: aug_cla_7_gem_wo_me80.png
# 2024-11-22 20:19:03,400 - INFO -
# Processing donor 8/84: aug_cla_8_gem_wo
# 2024-11-22 20:19:03,411 - INFO - ✓ Created workflow for random scenario: aug_cla_8_gem_wo_rand46.png
# 2024-11-22 20:19:03,415 - INFO - ✓ Created workflow for donor_dominant scenario: aug_cla_8_gem_wo_donor80.png
# 2024-11-22 20:19:03,420 - INFO - ✓ Created workflow for balanced scenario: aug_cla_8_gem_wo_blend50.png
# 2024-11-22 20:19:03,422 - INFO - ✓ Created workflow for me_dominant scenario: aug_cla_8_gem_wo_me80.png
# 2024-11-22 20:19:04,428 - INFO -
# Processing donor 9/84: aug_cla_9_gem_demo
# 2024-11-22 20:19:04,435 - INFO - ✓ Created workflow for random scenario: aug_cla_9_gem_demo_rand78.png
# 2024-11-22 20:19:04,439 - INFO - ✓ Created workflow for donor_dominant scenario: aug_cla_9_gem_demo_donor80.png
# 2024-11-22 20:19:04,442 - INFO - ✓ Created workflow for balanced scenario: aug_cla_9_gem_demo_blend50.png
# 2024-11-22 20:19:04,444 - INFO - ✓ Created workflow for me_dominant scenario: aug_cla_9_gem_demo_me80.png
# 2024-11-22 20:19:05,450 - INFO -
# Processing donor 10/84: aug_cla_9_gem_wo
# 2024-11-22 20:19:05,459 - INFO - ✓ Created workflow for random scenario: aug_cla_9_gem_wo_rand62.png
# 2024-11-22 20:19:05,461 - INFO - ✓ Created workflow for donor_dominant scenario: aug_cla_9_gem_wo_donor80.png
# 2024-11-22 20:19:05,463 - INFO - ✓ Created workflow for balanced scenario: aug_cla_9_gem_wo_blend50.png
# 2024-11-22 20:19:05,469 - INFO - ✓ Created workflow for me_dominant scenario: aug_cla_9_gem_wo_me80.png
# 2024-11-22 20:19:05,470 - INFO - Completed 10/84 donors
# 2024-11-22 20:19:06,475 - INFO -
# Processing donor 11/84: aug_gem_10_gem_wo
# 2024-11-22 20:19:06,481 - INFO - ✓ Created workflow for random scenario: aug_gem_10_gem_wo_rand38.png
# 2024-11-22 20:19:06,483 - INFO - ✓ Created workflow for donor_dominant scenario: aug_gem_10_gem_wo_donor80.png
# 2024-11-22 20:19:06,484 - INFO - ✓ Created workflow for balanced scenario: aug_gem_10_gem_wo_blend50.png
# 2024-11-22 20:19:06,486 - INFO - ✓ Created workflow for me_dominant scenario: aug_gem_10_gem_wo_me80.png
# 2024-11-22 20:19:07,492 - INFO -
# Processing donor 12/84: aug_gem_1_gem_wo
# 2024-11-22 20:19:07,499 - INFO - ✓ Created workflow for random scenario: aug_gem_1_gem_wo_rand60.png
# 2024-11-22 20:19:07,506 - INFO - ✓ Created workflow for donor_dominant scenario: aug_gem_1_gem_wo_donor80.png
# 2024-11-22 20:19:07,508 - INFO - ✓ Created workflow for balanced scenario: aug_gem_1_gem_wo_blend50.png
# 2024-11-22 20:19:07,509 - INFO - ✓ Created workflow for me_dominant scenario: aug_gem_1_gem_wo_me80.png
# 2024-11-22 20:19:08,515 - INFO -
# Processing donor 13/84: aug_gem_2_gem_demo
# 2024-11-22 20:19:08,523 - INFO - ✓ Created workflow for random scenario: aug_gem_2_gem_demo_rand72.png
# 2024-11-22 20:19:08,527 - INFO - ✓ Created workflow for donor_dominant scenario: aug_gem_2_gem_demo_donor80.png
# 2024-11-22 20:19:08,532 - INFO - ✓ Created workflow for balanced scenario: aug_gem_2_gem_demo_blend50.png
# 2024-11-22 20:19:08,538 - INFO - ✓ Created workflow for me_dominant scenario: aug_gem_2_gem_demo_me80.png
# 2024-11-22 20:19:09,544 - INFO -
# Processing donor 14/84: aug_gem_2_gem_wo
# 2024-11-22 20:19:09,553 - INFO - ✓ Created workflow for random scenario: aug_gem_2_gem_wo_rand62.png
# 2024-11-22 20:19:09,560 - INFO - ✓ Created workflow for donor_dominant scenario: aug_gem_2_gem_wo_donor80.png
# 2024-11-22 20:19:09,563 - INFO - ✓ Created workflow for balanced scenario: aug_gem_2_gem_wo_blend50.png
# 2024-11-22 20:19:09,565 - INFO - ✓ Created workflow for me_dominant scenario: aug_gem_2_gem_wo_me80.png
# 2024-11-22 20:19:10,567 - INFO -
# Processing donor 15/84: aug_gem_3_gem_demo
# 2024-11-22 20:19:10,572 - INFO - ✓ Created workflow for random scenario: aug_gem_3_gem_demo_rand68.png
# 2024-11-22 20:19:10,575 - INFO - ✓ Created workflow for donor_dominant scenario: aug_gem_3_gem_demo_donor80.png
# 2024-11-22 20:19:10,576 - INFO - ✓ Created workflow for balanced scenario: aug_gem_3_gem_demo_blend50.png
# 2024-11-22 20:19:10,578 - INFO - ✓ Created workflow for me_dominant scenario: aug_gem_3_gem_demo_me80.png
# 2024-11-22 20:19:11,583 - INFO -
# Processing donor 16/84: aug_gem_3_gem_wo
# 2024-11-22 20:19:11,588 - INFO - ✓ Created workflow for random scenario: aug_gem_3_gem_wo_rand42.png
# 2024-11-22 20:19:11,592 - INFO - ✓ Created workflow for donor_dominant scenario: aug_gem_3_gem_wo_donor80.png
# 2024-11-22 20:19:11,597 - INFO - ✓ Created workflow for balanced scenario: aug_gem_3_gem_wo_blend50.png
# 2024-11-22 20:19:11,599 - INFO - ✓ Created workflow for me_dominant scenario: aug_gem_3_gem_wo_me80.png
# 2024-11-22 20:19:12,605 - INFO -
# Processing donor 17/84: aug_gem_4_gem_demo
# 2024-11-22 20:19:12,613 - INFO - ✓ Created workflow for random scenario: aug_gem_4_gem_demo_rand40.png
# 2024-11-22 20:19:12,618 - INFO - ✓ Created workflow for donor_dominant scenario: aug_gem_4_gem_demo_donor80.png
# 2024-11-22 20:19:12,622 - INFO - ✓ Created workflow for balanced scenario: aug_gem_4_gem_demo_blend50.png
# 2024-11-22 20:19:12,628 - INFO - ✓ Created workflow for me_dominant scenario: aug_gem_4_gem_demo_me80.png
# 2024-11-22 20:19:13,633 - INFO -
# Processing donor 18/84: aug_gem_4_gem_wo
# 2024-11-22 20:19:13,644 - INFO - ✓ Created workflow for random scenario: aug_gem_4_gem_wo_rand25.png
# 2024-11-22 20:19:13,647 - INFO - ✓ Created workflow for donor_dominant scenario: aug_gem_4_gem_wo_donor80.png
# 2024-11-22 20:19:13,651 - INFO - ✓ Created workflow for balanced scenario: aug_gem_4_gem_wo_blend50.png
# 2024-11-22 20:19:13,654 - INFO - ✓ Created workflow for me_dominant scenario: aug_gem_4_gem_wo_me80.png
# 2024-11-22 20:19:14,660 - INFO -
# Processing donor 19/84: aug_gem_5_gem_demo
# 2024-11-22 20:19:14,672 - INFO - ✓ Created workflow for random scenario: aug_gem_5_gem_demo_rand60.png
# 2024-11-22 20:19:14,675 - INFO - ✓ Created workflow for donor_dominant scenario: aug_gem_5_gem_demo_donor80.png
# 2024-11-22 20:19:14,678 - INFO - ✓ Created workflow for balanced scenario: aug_gem_5_gem_demo_blend50.png
# 2024-11-22 20:19:14,686 - INFO - ✓ Created workflow for me_dominant scenario: aug_gem_5_gem_demo_me80.png
# 2024-11-22 20:19:15,691 - INFO -
# Processing donor 20/84: aug_gem_5_gem_wo
# 2024-11-22 20:19:15,695 - INFO - ✓ Created workflow for random scenario: aug_gem_5_gem_wo_rand21.png
# 2024-11-22 20:19:15,699 - INFO - ✓ Created workflow for donor_dominant scenario: aug_gem_5_gem_wo_donor80.png
# 2024-11-22 20:19:15,707 - INFO - ✓ Created workflow for balanced scenario: aug_gem_5_gem_wo_blend50.png
# 2024-11-22 20:19:15,708 - INFO - ✓ Created workflow for me_dominant scenario: aug_gem_5_gem_wo_me80.png
# 2024-11-22 20:19:15,708 - INFO - Completed 20/84 donors
# 2024-11-22 20:19:16,713 - INFO -
# Processing donor 21/84: aug_gem_6_gem_demo
# 2024-11-22 20:19:16,722 - INFO - ✓ Created workflow for random scenario: aug_gem_6_gem_demo_rand36.png
# 2024-11-22 20:19:16,725 - INFO - ✓ Created workflow for donor_dominant scenario: aug_gem_6_gem_demo_donor80.png
# 2024-11-22 20:19:16,734 - INFO - ✓ Created workflow for balanced scenario: aug_gem_6_gem_demo_blend50.png
# 2024-11-22 20:19:16,736 - INFO - ✓ Created workflow for me_dominant scenario: aug_gem_6_gem_demo_me80.png
# 2024-11-22 20:19:17,741 - INFO -
# Processing donor 22/84: aug_gem_6_gem_wo
# 2024-11-22 20:19:17,747 - INFO - ✓ Created workflow for random scenario: aug_gem_6_gem_wo_rand62.png
# 2024-11-22 20:19:17,750 - INFO - ✓ Created workflow for donor_dominant scenario: aug_gem_6_gem_wo_donor80.png
# 2024-11-22 20:19:17,752 - INFO - ✓ Created workflow for balanced scenario: aug_gem_6_gem_wo_blend50.png
# 2024-11-22 20:19:17,754 - INFO - ✓ Created workflow for me_dominant scenario: aug_gem_6_gem_wo_me80.png
# 2024-11-22 20:19:18,759 - INFO -
# Processing donor 23/84: aug_gem_7_gem_demo
# 2024-11-22 20:19:18,768 - INFO - ✓ Created workflow for random scenario: aug_gem_7_gem_demo_rand37.png
# 2024-11-22 20:19:18,776 - INFO - ✓ Created workflow for donor_dominant scenario: aug_gem_7_gem_demo_donor80.png
# 2024-11-22 20:19:18,778 - INFO - ✓ Created workflow for balanced scenario: aug_gem_7_gem_demo_blend50.png
# 2024-11-22 20:19:18,780 - INFO - ✓ Created workflow for me_dominant scenario: aug_gem_7_gem_demo_me80.png
# 2024-11-22 20:19:19,786 - INFO -
# Processing donor 24/84: aug_gem_8_gem_demo
# 2024-11-22 20:19:19,794 - INFO - ✓ Created workflow for random scenario: aug_gem_8_gem_demo_rand64.png
# 2024-11-22 20:19:19,804 - INFO - ✓ Created workflow for donor_dominant scenario: aug_gem_8_gem_demo_donor80.png
# 2024-11-22 20:19:19,807 - INFO - ✓ Created workflow for balanced scenario: aug_gem_8_gem_demo_blend50.png
# 2024-11-22 20:19:19,809 - INFO - ✓ Created workflow for me_dominant scenario: aug_gem_8_gem_demo_me80.png
# 2024-11-22 20:19:20,815 - INFO -
# Processing donor 25/84: aug_gem_8_gem_wo
# 2024-11-22 20:19:20,826 - INFO - ✓ Created workflow for random scenario: aug_gem_8_gem_wo_rand37.png
# 2024-11-22 20:19:20,830 - INFO - ✓ Created workflow for donor_dominant scenario: aug_gem_8_gem_wo_donor80.png
# 2024-11-22 20:19:20,836 - INFO - ✓ Created workflow for balanced scenario: aug_gem_8_gem_wo_blend50.png
# 2024-11-22 20:19:20,838 - INFO - ✓ Created workflow for me_dominant scenario: aug_gem_8_gem_wo_me80.png
# 2024-11-22 20:19:21,843 - INFO -
# Processing donor 26/84: aug_gem_9_gem_demo
# 2024-11-22 20:19:21,853 - INFO - ✓ Created workflow for random scenario: aug_gem_9_gem_demo_rand36.png
# 2024-11-22 20:19:21,856 - INFO - ✓ Created workflow for donor_dominant scenario: aug_gem_9_gem_demo_donor80.png
# 2024-11-22 20:19:21,863 - INFO - ✓ Created workflow for balanced scenario: aug_gem_9_gem_demo_blend50.png
# 2024-11-22 20:19:21,865 - INFO - ✓ Created workflow for me_dominant scenario: aug_gem_9_gem_demo_me80.png
# 2024-11-22 20:19:22,870 - INFO -
# Processing donor 27/84: aug_gem_9_gem_wo
# 2024-11-22 20:19:22,880 - INFO - ✓ Created workflow for random scenario: aug_gem_9_gem_wo_rand31.png
# 2024-11-22 20:19:22,883 - INFO - ✓ Created workflow for donor_dominant scenario: aug_gem_9_gem_wo_donor80.png
# 2024-11-22 20:19:22,886 - INFO - ✓ Created workflow for balanced scenario: aug_gem_9_gem_wo_blend50.png
# 2024-11-22 20:19:22,891 - INFO - ✓ Created workflow for me_dominant scenario: aug_gem_9_gem_wo_me80.png
# 2024-11-22 20:19:23,897 - INFO -
# Processing donor 28/84: aug_gpt_10_gem_demo
# 2024-11-22 20:19:23,899 - INFO - ✓ Created workflow for random scenario: aug_gpt_10_gem_demo_rand27.png
# 2024-11-22 20:19:23,901 - INFO - ✓ Created workflow for donor_dominant scenario: aug_gpt_10_gem_demo_donor80.png
# 2024-11-22 20:19:23,902 - INFO - ✓ Created workflow for balanced scenario: aug_gpt_10_gem_demo_blend50.png
# 2024-11-22 20:19:23,903 - INFO - ✓ Created workflow for me_dominant scenario: aug_gpt_10_gem_demo_me80.png
# 2024-11-22 20:19:24,905 - INFO -
# Processing donor 29/84: aug_gpt_10_gem_wo
# 2024-11-22 20:19:24,909 - INFO - ✓ Created workflow for random scenario: aug_gpt_10_gem_wo_rand28.png
# 2024-11-22 20:19:24,912 - INFO - ✓ Created workflow for donor_dominant scenario: aug_gpt_10_gem_wo_donor80.png
# 2024-11-22 20:19:24,914 - INFO - ✓ Created workflow for balanced scenario: aug_gpt_10_gem_wo_blend50.png
# 2024-11-22 20:19:24,917 - INFO - ✓ Created workflow for me_dominant scenario: aug_gpt_10_gem_wo_me80.png
# 2024-11-22 20:19:25,922 - INFO -
# Processing donor 30/84: aug_gpt_1_gem_demo
# 2024-11-22 20:19:25,932 - INFO - ✓ Created workflow for random scenario: aug_gpt_1_gem_demo_rand79.png
# 2024-11-22 20:19:25,938 - INFO - ✓ Created workflow for donor_dominant scenario: aug_gpt_1_gem_demo_donor80.png
# 2024-11-22 20:19:25,941 - INFO - ✓ Created workflow for balanced scenario: aug_gpt_1_gem_demo_blend50.png
# 2024-11-22 20:19:25,943 - INFO - ✓ Created workflow for me_dominant scenario: aug_gpt_1_gem_demo_me80.png
# 2024-11-22 20:19:25,943 - INFO - Completed 30/84 donors
# 2024-11-22 20:19:26,949 - INFO -
# Processing donor 31/84: aug_gpt_1_gem_wo
# 2024-11-22 20:19:26,956 - INFO - ✓ Created workflow for random scenario: aug_gpt_1_gem_wo_rand24.png
# 2024-11-22 20:19:26,959 - INFO - ✓ Created workflow for donor_dominant scenario: aug_gpt_1_gem_wo_donor80.png
# 2024-11-22 20:19:26,967 - INFO - ✓ Created workflow for balanced scenario: aug_gpt_1_gem_wo_blend50.png
# 2024-11-22 20:19:26,970 - INFO - ✓ Created workflow for me_dominant scenario: aug_gpt_1_gem_wo_me80.png
# 2024-11-22 20:19:27,975 - INFO -
# Processing donor 32/84: aug_gpt_2_gem_wo
# 2024-11-22 20:19:27,985 - INFO - ✓ Created workflow for random scenario: aug_gpt_2_gem_wo_rand24.png
# 2024-11-22 20:19:27,988 - INFO - ✓ Created workflow for donor_dominant scenario: aug_gpt_2_gem_wo_donor80.png
# 2024-11-22 20:19:27,996 - INFO - ✓ Created workflow for balanced scenario: aug_gpt_2_gem_wo_blend50.png
# 2024-11-22 20:19:27,998 - INFO - ✓ Created workflow for me_dominant scenario: aug_gpt_2_gem_wo_me80.png
# 2024-11-22 20:19:29,004 - INFO -
# Processing donor 33/84: aug_gpt_3_gem_demo
# 2024-11-22 20:19:29,009 - INFO - ✓ Created workflow for random scenario: aug_gpt_3_gem_demo_rand20.png
# 2024-11-22 20:19:29,012 - INFO - ✓ Created workflow for donor_dominant scenario: aug_gpt_3_gem_demo_donor80.png
# 2024-11-22 20:19:29,013 - INFO - ✓ Created workflow for balanced scenario: aug_gpt_3_gem_demo_blend50.png
# 2024-11-22 20:19:29,015 - INFO - ✓ Created workflow for me_dominant scenario: aug_gpt_3_gem_demo_me80.png
# 2024-11-22 20:19:30,021 - INFO -
# Processing donor 34/84: aug_gpt_3_gem_wo
# 2024-11-22 20:19:30,033 - INFO - ✓ Created workflow for random scenario: aug_gpt_3_gem_wo_rand54.png
# 2024-11-22 20:19:30,037 - INFO - ✓ Created workflow for donor_dominant scenario: aug_gpt_3_gem_wo_donor80.png
# 2024-11-22 20:19:30,040 - INFO - ✓ Created workflow for balanced scenario: aug_gpt_3_gem_wo_blend50.png
# 2024-11-22 20:19:30,042 - INFO - ✓ Created workflow for me_dominant scenario: aug_gpt_3_gem_wo_me80.png
# 2024-11-22 20:19:31,047 - INFO -
# Processing donor 35/84: aug_gpt_4_gem_demo
# 2024-11-22 20:19:31,054 - INFO - ✓ Created workflow for random scenario: aug_gpt_4_gem_demo_rand57.png
# 2024-11-22 20:19:31,060 - INFO - ✓ Created workflow for donor_dominant scenario: aug_gpt_4_gem_demo_donor80.png
# 2024-11-22 20:19:31,063 - INFO - ✓ Created workflow for balanced scenario: aug_gpt_4_gem_demo_blend50.png
# 2024-11-22 20:19:31,066 - INFO - ✓ Created workflow for me_dominant scenario: aug_gpt_4_gem_demo_me80.png
# 2024-11-22 20:19:32,072 - INFO -
# Processing donor 36/84: aug_gpt_4_gem_wo
# 2024-11-22 20:19:32,077 - INFO - ✓ Created workflow for random scenario: aug_gpt_4_gem_wo_rand44.png
# 2024-11-22 20:19:32,080 - INFO - ✓ Created workflow for donor_dominant scenario: aug_gpt_4_gem_wo_donor80.png
# 2024-11-22 20:19:32,083 - INFO - ✓ Created workflow for balanced scenario: aug_gpt_4_gem_wo_blend50.png
# 2024-11-22 20:19:32,087 - INFO - ✓ Created workflow for me_dominant scenario: aug_gpt_4_gem_wo_me80.png
# 2024-11-22 20:19:33,093 - INFO -
# Processing donor 37/84: aug_gpt_5_gem_demo
# 2024-11-22 20:19:33,099 - INFO - ✓ Created workflow for random scenario: aug_gpt_5_gem_demo_rand50.png
# 2024-11-22 20:19:33,102 - INFO - ✓ Created workflow for donor_dominant scenario: aug_gpt_5_gem_demo_donor80.png
# 2024-11-22 20:19:33,105 - INFO - ✓ Created workflow for balanced scenario: aug_gpt_5_gem_demo_blend50.png
# 2024-11-22 20:19:33,107 - INFO - ✓ Created workflow for me_dominant scenario: aug_gpt_5_gem_demo_me80.png
# 2024-11-22 20:19:34,113 - INFO -
# Processing donor 38/84: aug_gpt_6_gem_demo
# 2024-11-22 20:19:34,121 - INFO - ✓ Created workflow for random scenario: aug_gpt_6_gem_demo_rand53.png
# 2024-11-22 20:19:34,123 - INFO - ✓ Created workflow for donor_dominant scenario: aug_gpt_6_gem_demo_donor80.png
# 2024-11-22 20:19:34,126 - INFO - ✓ Created workflow for balanced scenario: aug_gpt_6_gem_demo_blend50.png
# 2024-11-22 20:19:34,128 - INFO - ✓ Created workflow for me_dominant scenario: aug_gpt_6_gem_demo_me80.png
# 2024-11-22 20:19:35,134 - INFO -
# Processing donor 39/84: aug_gpt_6_gem_wo
# 2024-11-22 20:19:35,142 - INFO - ✓ Created workflow for random scenario: aug_gpt_6_gem_wo_rand33.png
# 2024-11-22 20:19:35,145 - INFO - ✓ Created workflow for donor_dominant scenario: aug_gpt_6_gem_wo_donor80.png
# 2024-11-22 20:19:35,150 - INFO - ✓ Created workflow for balanced scenario: aug_gpt_6_gem_wo_blend50.png
# 2024-11-22 20:19:35,156 - INFO - ✓ Created workflow for me_dominant scenario: aug_gpt_6_gem_wo_me80.png
# 2024-11-22 20:19:36,162 - INFO -
# Processing donor 40/84: aug_gpt_7_gem_demo
# 2024-11-22 20:19:36,168 - INFO - ✓ Created workflow for random scenario: aug_gpt_7_gem_demo_rand52.png
# 2024-11-22 20:19:36,175 - INFO - ✓ Created workflow for donor_dominant scenario: aug_gpt_7_gem_demo_donor80.png
# 2024-11-22 20:19:36,178 - INFO - ✓ Created workflow for balanced scenario: aug_gpt_7_gem_demo_blend50.png
# 2024-11-22 20:19:36,180 - INFO - ✓ Created workflow for me_dominant scenario: aug_gpt_7_gem_demo_me80.png
# 2024-11-22 20:19:36,181 - INFO - Completed 40/84 donors
# 2024-11-22 20:19:37,186 - INFO -
# Processing donor 41/84: aug_gpt_7_gem_wo
# 2024-11-22 20:19:37,195 - INFO - ✓ Created workflow for random scenario: aug_gpt_7_gem_wo_rand26.png
# 2024-11-22 20:19:37,199 - INFO - ✓ Created workflow for donor_dominant scenario: aug_gpt_7_gem_wo_donor80.png
# 2024-11-22 20:19:37,204 - INFO - ✓ Created workflow for balanced scenario: aug_gpt_7_gem_wo_blend50.png
# 2024-11-22 20:19:37,206 - INFO - ✓ Created workflow for me_dominant scenario: aug_gpt_7_gem_wo_me80.png
# 2024-11-22 20:19:38,211 - INFO -
# Processing donor 42/84: aug_gpt_8_gem_wo
# 2024-11-22 20:19:38,216 - INFO - ✓ Created workflow for random scenario: aug_gpt_8_gem_wo_rand24.png
# 2024-11-22 20:19:38,220 - INFO - ✓ Created workflow for donor_dominant scenario: aug_gpt_8_gem_wo_donor80.png
# 2024-11-22 20:19:38,225 - INFO - ✓ Created workflow for balanced scenario: aug_gpt_8_gem_wo_blend50.png
# 2024-11-22 20:19:38,227 - INFO - ✓ Created workflow for me_dominant scenario: aug_gpt_8_gem_wo_me80.png
# 2024-11-22 20:19:39,233 - INFO -
# Processing donor 43/84: aug_gpt_9_gem_demo
# 2024-11-22 20:19:39,244 - INFO - ✓ Created workflow for random scenario: aug_gpt_9_gem_demo_rand37.png
# 2024-11-22 20:19:39,246 - INFO - ✓ Created workflow for donor_dominant scenario: aug_gpt_9_gem_demo_donor80.png
# 2024-11-22 20:19:39,249 - INFO - ✓ Created workflow for balanced scenario: aug_gpt_9_gem_demo_blend50.png
# 2024-11-22 20:19:39,255 - INFO - ✓ Created workflow for me_dominant scenario: aug_gpt_9_gem_demo_me80.png
# 2024-11-22 20:19:40,260 - INFO -
# Processing donor 44/84: aug_gpt_9_gem_wo
# 2024-11-22 20:19:40,268 - INFO - ✓ Created workflow for random scenario: aug_gpt_9_gem_wo_rand37.png
# 2024-11-22 20:19:40,270 - INFO - ✓ Created workflow for donor_dominant scenario: aug_gpt_9_gem_wo_donor80.png
# 2024-11-22 20:19:40,277 - INFO - ✓ Created workflow for balanced scenario: aug_gpt_9_gem_wo_blend50.png
# 2024-11-22 20:19:40,278 - INFO - ✓ Created workflow for me_dominant scenario: aug_gpt_9_gem_wo_me80.png
# 2024-11-22 20:19:41,281 - INFO -
# Processing donor 45/84: org_cla_1_gem_demo
# 2024-11-22 20:19:41,284 - INFO - ✓ Created workflow for random scenario: org_cla_1_gem_demo_rand57.png
# 2024-11-22 20:19:41,287 - INFO - ✓ Created workflow for donor_dominant scenario: org_cla_1_gem_demo_donor80.png
# 2024-11-22 20:19:41,289 - INFO - ✓ Created workflow for balanced scenario: org_cla_1_gem_demo_blend50.png
# 2024-11-22 20:19:41,290 - INFO - ✓ Created workflow for me_dominant scenario: org_cla_1_gem_demo_me80.png
# 2024-11-22 20:19:42,296 - INFO -
# Processing donor 46/84: org_cla_2_gem_demo
# 2024-11-22 20:19:42,302 - INFO - ✓ Created workflow for random scenario: org_cla_2_gem_demo_rand37.png
# 2024-11-22 20:19:42,306 - INFO - ✓ Created workflow for donor_dominant scenario: org_cla_2_gem_demo_donor80.png
# 2024-11-22 20:19:42,310 - INFO - ✓ Created workflow for balanced scenario: org_cla_2_gem_demo_blend50.png
# 2024-11-22 20:19:42,312 - INFO - ✓ Created workflow for me_dominant scenario: org_cla_2_gem_demo_me80.png
# 2024-11-22 20:19:43,318 - INFO -
# Processing donor 47/84: org_cla_3_gem_demo
# 2024-11-22 20:19:43,323 - INFO - ✓ Created workflow for random scenario: org_cla_3_gem_demo_rand65.png
# 2024-11-22 20:19:43,326 - INFO - ✓ Created workflow for donor_dominant scenario: org_cla_3_gem_demo_donor80.png
# 2024-11-22 20:19:43,328 - INFO - ✓ Created workflow for balanced scenario: org_cla_3_gem_demo_blend50.png
# 2024-11-22 20:19:43,329 - INFO - ✓ Created workflow for me_dominant scenario: org_cla_3_gem_demo_me80.png
# 2024-11-22 20:19:44,335 - INFO -
# Processing donor 48/84: org_cla_3_gem_wo
# 2024-11-22 20:19:44,340 - INFO - ✓ Created workflow for random scenario: org_cla_3_gem_wo_rand42.png
# 2024-11-22 20:19:44,347 - INFO - ✓ Created workflow for donor_dominant scenario: org_cla_3_gem_wo_donor80.png
# 2024-11-22 20:19:44,348 - INFO - ✓ Created workflow for balanced scenario: org_cla_3_gem_wo_blend50.png
# 2024-11-22 20:19:44,350 - INFO - ✓ Created workflow for me_dominant scenario: org_cla_3_gem_wo_me80.png
# 2024-11-22 20:19:45,355 - INFO -
# Processing donor 49/84: org_cla_4_gem_demo
# 2024-11-22 20:19:45,357 - INFO - ✓ Created workflow for random scenario: org_cla_4_gem_demo_rand78.png
# 2024-11-22 20:19:45,358 - INFO - ✓ Created workflow for donor_dominant scenario: org_cla_4_gem_demo_donor80.png
# 2024-11-22 20:19:45,359 - INFO - ✓ Created workflow for balanced scenario: org_cla_4_gem_demo_blend50.png
# 2024-11-22 20:19:45,361 - INFO - ✓ Created workflow for me_dominant scenario: org_cla_4_gem_demo_me80.png
# 2024-11-22 20:19:46,366 - INFO -
# Processing donor 50/84: org_cla_4_gem_wo
# 2024-11-22 20:19:46,371 - INFO - ✓ Created workflow for random scenario: org_cla_4_gem_wo_rand74.png
# 2024-11-22 20:19:46,374 - INFO - ✓ Created workflow for donor_dominant scenario: org_cla_4_gem_wo_donor80.png
# 2024-11-22 20:19:46,380 - INFO - ✓ Created workflow for balanced scenario: org_cla_4_gem_wo_blend50.png
# 2024-11-22 20:19:46,382 - INFO - ✓ Created workflow for me_dominant scenario: org_cla_4_gem_wo_me80.png
# 2024-11-22 20:19:46,382 - INFO - Completed 50/84 donors
# 2024-11-22 20:19:47,388 - INFO -
# Processing donor 51/84: org_cla_6_gem_demo
# 2024-11-22 20:19:47,395 - INFO - ✓ Created workflow for random scenario: org_cla_6_gem_demo_rand56.png
# 2024-11-22 20:19:47,399 - INFO - ✓ Created workflow for donor_dominant scenario: org_cla_6_gem_demo_donor80.png
# 2024-11-22 20:19:47,403 - INFO - ✓ Created workflow for balanced scenario: org_cla_6_gem_demo_blend50.png
# 2024-11-22 20:19:47,409 - INFO - ✓ Created workflow for me_dominant scenario: org_cla_6_gem_demo_me80.png
# 2024-11-22 20:19:48,415 - INFO -
# Processing donor 52/84: org_cla_9_gem_demo
# 2024-11-22 20:19:48,424 - INFO - ✓ Created workflow for random scenario: org_cla_9_gem_demo_rand49.png
# 2024-11-22 20:19:48,429 - INFO - ✓ Created workflow for donor_dominant scenario: org_cla_9_gem_demo_donor80.png
# 2024-11-22 20:19:48,435 - INFO - ✓ Created workflow for balanced scenario: org_cla_9_gem_demo_blend50.png
# 2024-11-22 20:19:48,437 - INFO - ✓ Created workflow for me_dominant scenario: org_cla_9_gem_demo_me80.png
# 2024-11-22 20:19:49,442 - INFO -
# Processing donor 53/84: org_gem_10_gem_demo
# 2024-11-22 20:19:49,450 - INFO - ✓ Created workflow for random scenario: org_gem_10_gem_demo_rand56.png
# 2024-11-22 20:19:49,455 - INFO - ✓ Created workflow for donor_dominant scenario: org_gem_10_gem_demo_donor80.png
# 2024-11-22 20:19:49,461 - INFO - ✓ Created workflow for balanced scenario: org_gem_10_gem_demo_blend50.png
# 2024-11-22 20:19:49,463 - INFO - ✓ Created workflow for me_dominant scenario: org_gem_10_gem_demo_me80.png
# 2024-11-22 20:19:50,469 - INFO -
# Processing donor 54/84: org_gem_10_gem_wo
# 2024-11-22 20:19:50,470 - INFO - ✓ Created workflow for random scenario: org_gem_10_gem_wo_rand70.png
# 2024-11-22 20:19:50,471 - INFO - ✓ Created workflow for donor_dominant scenario: org_gem_10_gem_wo_donor80.png
# 2024-11-22 20:19:50,473 - INFO - ✓ Created workflow for balanced scenario: org_gem_10_gem_wo_blend50.png
# 2024-11-22 20:19:50,474 - INFO - ✓ Created workflow for me_dominant scenario: org_gem_10_gem_wo_me80.png
# 2024-11-22 20:19:51,479 - INFO -
# Processing donor 55/84: org_gem_1_gem_demo
# 2024-11-22 20:19:51,489 - INFO - ✓ Created workflow for random scenario: org_gem_1_gem_demo_rand65.png
# 2024-11-22 20:19:51,493 - INFO - ✓ Created workflow for donor_dominant scenario: org_gem_1_gem_demo_donor80.png
# 2024-11-22 20:19:51,499 - INFO - ✓ Created workflow for balanced scenario: org_gem_1_gem_demo_blend50.png
# 2024-11-22 20:19:51,501 - INFO - ✓ Created workflow for me_dominant scenario: org_gem_1_gem_demo_me80.png
# 2024-11-22 20:19:52,506 - INFO -
# Processing donor 56/84: org_gem_1_gem_wo
# 2024-11-22 20:19:52,513 - INFO - ✓ Created workflow for random scenario: org_gem_1_gem_wo_rand33.png
# 2024-11-22 20:19:52,518 - INFO - ✓ Created workflow for donor_dominant scenario: org_gem_1_gem_wo_donor80.png
# 2024-11-22 20:19:52,521 - INFO - ✓ Created workflow for balanced scenario: org_gem_1_gem_wo_blend50.png
# 2024-11-22 20:19:52,523 - INFO - ✓ Created workflow for me_dominant scenario: org_gem_1_gem_wo_me80.png
# 2024-11-22 20:19:53,529 - INFO -
# Processing donor 57/84: org_gem_2_gem_demo
# 2024-11-22 20:19:53,537 - INFO - ✓ Created workflow for random scenario: org_gem_2_gem_demo_rand33.png
# 2024-11-22 20:19:53,539 - INFO - ✓ Created workflow for donor_dominant scenario: org_gem_2_gem_demo_donor80.png
# 2024-11-22 20:19:53,542 - INFO - ✓ Created workflow for balanced scenario: org_gem_2_gem_demo_blend50.png
# 2024-11-22 20:19:53,549 - INFO - ✓ Created workflow for me_dominant scenario: org_gem_2_gem_demo_me80.png
# 2024-11-22 20:19:54,557 - INFO -
# Processing donor 58/84: org_gem_2_gem_wo
# 2024-11-22 20:19:54,564 - INFO - ✓ Created workflow for random scenario: org_gem_2_gem_wo_rand21.png
# 2024-11-22 20:19:54,566 - INFO - ✓ Created workflow for donor_dominant scenario: org_gem_2_gem_wo_donor80.png
# 2024-11-22 20:19:54,568 - INFO - ✓ Created workflow for balanced scenario: org_gem_2_gem_wo_blend50.png
# 2024-11-22 20:19:54,570 - INFO - ✓ Created workflow for me_dominant scenario: org_gem_2_gem_wo_me80.png
# 2024-11-22 20:19:55,573 - INFO -
# Processing donor 59/84: org_gem_3_gem_demo
# 2024-11-22 20:19:55,576 - INFO - ✓ Created workflow for random scenario: org_gem_3_gem_demo_rand75.png
# 2024-11-22 20:19:55,578 - INFO - ✓ Created workflow for donor_dominant scenario: org_gem_3_gem_demo_donor80.png
# 2024-11-22 20:19:55,583 - INFO - ✓ Created workflow for balanced scenario: org_gem_3_gem_demo_blend50.png
# 2024-11-22 20:19:55,585 - INFO - ✓ Created workflow for me_dominant scenario: org_gem_3_gem_demo_me80.png
# 2024-11-22 20:19:56,590 - INFO -
# Processing donor 60/84: org_gem_3_gem_wo
# 2024-11-22 20:19:56,596 - INFO - ✓ Created workflow for random scenario: org_gem_3_gem_wo_rand75.png
# 2024-11-22 20:19:56,603 - INFO - ✓ Created workflow for donor_dominant scenario: org_gem_3_gem_wo_donor80.png
# 2024-11-22 20:19:56,606 - INFO - ✓ Created workflow for balanced scenario: org_gem_3_gem_wo_blend50.png
# 2024-11-22 20:19:56,608 - INFO - ✓ Created workflow for me_dominant scenario: org_gem_3_gem_wo_me80.png
# 2024-11-22 20:19:56,608 - INFO - Completed 60/84 donors
# 2024-11-22 20:19:57,614 - INFO -
# Processing donor 61/84: org_gem_4_gem_demo
# 2024-11-22 20:19:57,621 - INFO - ✓ Created workflow for random scenario: org_gem_4_gem_demo_rand28.png
# 2024-11-22 20:19:57,626 - INFO - ✓ Created workflow for donor_dominant scenario: org_gem_4_gem_demo_donor80.png
# 2024-11-22 20:19:57,632 - INFO - ✓ Created workflow for balanced scenario: org_gem_4_gem_demo_blend50.png
# 2024-11-22 20:19:57,634 - INFO - ✓ Created workflow for me_dominant scenario: org_gem_4_gem_demo_me80.png
# 2024-11-22 20:19:58,640 - INFO -
# Processing donor 62/84: org_gem_4_gem_wo
# 2024-11-22 20:19:58,646 - INFO - ✓ Created workflow for random scenario: org_gem_4_gem_wo_rand30.png
# 2024-11-22 20:19:58,651 - INFO - ✓ Created workflow for donor_dominant scenario: org_gem_4_gem_wo_donor80.png
# 2024-11-22 20:19:58,659 - INFO - ✓ Created workflow for balanced scenario: org_gem_4_gem_wo_blend50.png
# 2024-11-22 20:19:58,661 - INFO - ✓ Created workflow for me_dominant scenario: org_gem_4_gem_wo_me80.png
# 2024-11-22 20:19:59,667 - INFO -
# Processing donor 63/84: org_gem_5_gem_wo
# 2024-11-22 20:19:59,675 - INFO - ✓ Created workflow for random scenario: org_gem_5_gem_wo_rand66.png
# 2024-11-22 20:19:59,680 - INFO - ✓ Created workflow for donor_dominant scenario: org_gem_5_gem_wo_donor80.png
# 2024-11-22 20:19:59,687 - INFO - ✓ Created workflow for balanced scenario: org_gem_5_gem_wo_blend50.png
# 2024-11-22 20:19:59,689 - INFO - ✓ Created workflow for me_dominant scenario: org_gem_5_gem_wo_me80.png
# 2024-11-22 20:20:00,693 - INFO -
# Processing donor 64/84: org_gem_6_gem_wo
# 2024-11-22 20:20:00,695 - INFO - ✓ Created workflow for random scenario: org_gem_6_gem_wo_rand49.png
# 2024-11-22 20:20:00,696 - INFO - ✓ Created workflow for donor_dominant scenario: org_gem_6_gem_wo_donor80.png
# 2024-11-22 20:20:00,698 - INFO - ✓ Created workflow for balanced scenario: org_gem_6_gem_wo_blend50.png
# 2024-11-22 20:20:00,699 - INFO - ✓ Created workflow for me_dominant scenario: org_gem_6_gem_wo_me80.png
# 2024-11-22 20:20:01,704 - INFO -
# Processing donor 65/84: org_gem_7_gem_demo
# 2024-11-22 20:20:01,713 - INFO - ✓ Created workflow for random scenario: org_gem_7_gem_demo_rand43.png
# 2024-11-22 20:20:01,718 - INFO - ✓ Created workflow for donor_dominant scenario: org_gem_7_gem_demo_donor80.png
# 2024-11-22 20:20:01,721 - INFO - ✓ Created workflow for balanced scenario: org_gem_7_gem_demo_blend50.png
# 2024-11-22 20:20:01,727 - INFO - ✓ Created workflow for me_dominant scenario: org_gem_7_gem_demo_me80.png
# 2024-11-22 20:20:02,733 - INFO -
# Processing donor 66/84: org_gem_7_gem_wo
# 2024-11-22 20:20:02,740 - INFO - ✓ Created workflow for random scenario: org_gem_7_gem_wo_rand72.png
# 2024-11-22 20:20:02,745 - INFO - ✓ Created workflow for donor_dominant scenario: org_gem_7_gem_wo_donor80.png
# 2024-11-22 20:20:02,748 - INFO - ✓ Created workflow for balanced scenario: org_gem_7_gem_wo_blend50.png
# 2024-11-22 20:20:02,752 - INFO - ✓ Created workflow for me_dominant scenario: org_gem_7_gem_wo_me80.png
# 2024-11-22 20:20:03,757 - INFO -
# Processing donor 67/84: org_gem_8_gem_demo
# 2024-11-22 20:20:03,764 - INFO - ✓ Created workflow for random scenario: org_gem_8_gem_demo_rand80.png
# 2024-11-22 20:20:03,768 - INFO - ✓ Created workflow for donor_dominant scenario: org_gem_8_gem_demo_donor80.png
# 2024-11-22 20:20:03,773 - INFO - ✓ Created workflow for balanced scenario: org_gem_8_gem_demo_blend50.png
# 2024-11-22 20:20:03,775 - INFO - ✓ Created workflow for me_dominant scenario: org_gem_8_gem_demo_me80.png
# 2024-11-22 20:20:04,781 - INFO -
# Processing donor 68/84: org_gem_8_gem_wo
# 2024-11-22 20:20:04,788 - INFO - ✓ Created workflow for random scenario: org_gem_8_gem_wo_rand59.png
# 2024-11-22 20:20:04,791 - INFO - ✓ Created workflow for donor_dominant scenario: org_gem_8_gem_wo_donor80.png
# 2024-11-22 20:20:04,792 - INFO - ✓ Created workflow for balanced scenario: org_gem_8_gem_wo_blend50.png
# 2024-11-22 20:20:04,796 - INFO - ✓ Created workflow for me_dominant scenario: org_gem_8_gem_wo_me80.png
# 2024-11-22 20:20:05,801 - INFO -
# Processing donor 69/84: org_gem_9_gem_wo
# 2024-11-22 20:20:05,804 - INFO - ✓ Created workflow for random scenario: org_gem_9_gem_wo_rand35.png
# 2024-11-22 20:20:05,805 - INFO - ✓ Created workflow for donor_dominant scenario: org_gem_9_gem_wo_donor80.png
# 2024-11-22 20:20:05,807 - INFO - ✓ Created workflow for balanced scenario: org_gem_9_gem_wo_blend50.png
# 2024-11-22 20:20:05,808 - INFO - ✓ Created workflow for me_dominant scenario: org_gem_9_gem_wo_me80.png
# 2024-11-22 20:20:06,814 - INFO -
# Processing donor 70/84: org_gpt_10_gem_wo
# 2024-11-22 20:20:06,824 - INFO - ✓ Created workflow for random scenario: org_gpt_10_gem_wo_rand75.png
# 2024-11-22 20:20:06,829 - INFO - ✓ Created workflow for donor_dominant scenario: org_gpt_10_gem_wo_donor80.png
# 2024-11-22 20:20:06,835 - INFO - ✓ Created workflow for balanced scenario: org_gpt_10_gem_wo_blend50.png
# 2024-11-22 20:20:06,837 - INFO - ✓ Created workflow for me_dominant scenario: org_gpt_10_gem_wo_me80.png
# 2024-11-22 20:20:06,838 - INFO - Completed 70/84 donors
# 2024-11-22 20:20:07,843 - INFO -
# Processing donor 71/84: org_gpt_1_gem_wo
# 2024-11-22 20:20:07,850 - INFO - ✓ Created workflow for random scenario: org_gpt_1_gem_wo_rand37.png
# 2024-11-22 20:20:07,859 - INFO - ✓ Created workflow for donor_dominant scenario: org_gpt_1_gem_wo_donor80.png
# 2024-11-22 20:20:07,862 - INFO - ✓ Created workflow for balanced scenario: org_gpt_1_gem_wo_blend50.png
# 2024-11-22 20:20:07,864 - INFO - ✓ Created workflow for me_dominant scenario: org_gpt_1_gem_wo_me80.png
# 2024-11-22 20:20:08,870 - INFO -
# Processing donor 72/84: org_gpt_2_gem_demo
# 2024-11-22 20:20:08,880 - INFO - ✓ Created workflow for random scenario: org_gpt_2_gem_demo_rand65.png
# 2024-11-22 20:20:08,883 - INFO - ✓ Created workflow for donor_dominant scenario: org_gpt_2_gem_demo_donor80.png
# 2024-11-22 20:20:08,885 - INFO - ✓ Created workflow for balanced scenario: org_gpt_2_gem_demo_blend50.png
# 2024-11-22 20:20:08,890 - INFO - ✓ Created workflow for me_dominant scenario: org_gpt_2_gem_demo_me80.png
# 2024-11-22 20:20:09,892 - INFO -
# Processing donor 73/84: org_gpt_2_gem_wo
# 2024-11-22 20:20:09,897 - INFO - ✓ Created workflow for random scenario: org_gpt_2_gem_wo_rand60.png
# 2024-11-22 20:20:09,900 - INFO - ✓ Created workflow for donor_dominant scenario: org_gpt_2_gem_wo_donor80.png
# 2024-11-22 20:20:09,905 - INFO - ✓ Created workflow for balanced scenario: org_gpt_2_gem_wo_blend50.png
# 2024-11-22 20:20:09,912 - INFO - ✓ Created workflow for me_dominant scenario: org_gpt_2_gem_wo_me80.png
# 2024-11-22 20:20:10,917 - INFO -
# Processing donor 74/84: org_gpt_3_gem_demo
# 2024-11-22 20:20:10,921 - INFO - ✓ Created workflow for random scenario: org_gpt_3_gem_demo_rand43.png
# 2024-11-22 20:20:10,923 - INFO - ✓ Created workflow for donor_dominant scenario: org_gpt_3_gem_demo_donor80.png
# 2024-11-22 20:20:10,925 - INFO - ✓ Created workflow for balanced scenario: org_gpt_3_gem_demo_blend50.png
# 2024-11-22 20:20:10,927 - INFO - ✓ Created workflow for me_dominant scenario: org_gpt_3_gem_demo_me80.png
# 2024-11-22 20:20:11,932 - INFO -
# Processing donor 75/84: org_gpt_3_gem_wo
# 2024-11-22 20:20:11,941 - INFO - ✓ Created workflow for random scenario: org_gpt_3_gem_wo_rand27.png
# 2024-11-22 20:20:11,946 - INFO - ✓ Created workflow for donor_dominant scenario: org_gpt_3_gem_wo_donor80.png
# 2024-11-22 20:20:11,949 - INFO - ✓ Created workflow for balanced scenario: org_gpt_3_gem_wo_blend50.png
# 2024-11-22 20:20:11,954 - INFO - ✓ Created workflow for me_dominant scenario: org_gpt_3_gem_wo_me80.png
# 2024-11-22 20:20:12,960 - INFO -
# Processing donor 76/84: org_gpt_4_gem_wo
# 2024-11-22 20:20:12,966 - INFO - ✓ Created workflow for random scenario: org_gpt_4_gem_wo_rand23.png
# 2024-11-22 20:20:12,969 - INFO - ✓ Created workflow for donor_dominant scenario: org_gpt_4_gem_wo_donor80.png
# 2024-11-22 20:20:12,971 - INFO - ✓ Created workflow for balanced scenario: org_gpt_4_gem_wo_blend50.png
# 2024-11-22 20:20:12,976 - INFO - ✓ Created workflow for me_dominant scenario: org_gpt_4_gem_wo_me80.png
# 2024-11-22 20:20:13,982 - INFO -
# Processing donor 77/84: org_gpt_5_gem_wo
# 2024-11-22 20:20:13,988 - INFO - ✓ Created workflow for random scenario: org_gpt_5_gem_wo_rand78.png
# 2024-11-22 20:20:13,991 - INFO - ✓ Created workflow for donor_dominant scenario: org_gpt_5_gem_wo_donor80.png
# 2024-11-22 20:20:13,993 - INFO - ✓ Created workflow for balanced scenario: org_gpt_5_gem_wo_blend50.png
# 2024-11-22 20:20:13,994 - INFO - ✓ Created workflow for me_dominant scenario: org_gpt_5_gem_wo_me80.png
# 2024-11-22 20:20:15,000 - INFO -
# Processing donor 78/84: org_gpt_6_gem_demo
# 2024-11-22 20:20:15,003 - INFO - ✓ Created workflow for random scenario: org_gpt_6_gem_demo_rand26.png
# 2024-11-22 20:20:15,006 - INFO - ✓ Created workflow for donor_dominant scenario: org_gpt_6_gem_demo_donor80.png
# 2024-11-22 20:20:15,012 - INFO - ✓ Created workflow for balanced scenario: org_gpt_6_gem_demo_blend50.png
# 2024-11-22 20:20:15,014 - INFO - ✓ Created workflow for me_dominant scenario: org_gpt_6_gem_demo_me80.png
# 2024-11-22 20:20:16,020 - INFO -
# Processing donor 79/84: org_gpt_6_gem_wo
# 2024-11-22 20:20:16,023 - INFO - ✓ Created workflow for random scenario: org_gpt_6_gem_wo_rand38.png
# 2024-11-22 20:20:16,024 - INFO - ✓ Created workflow for donor_dominant scenario: org_gpt_6_gem_wo_donor80.png
# 2024-11-22 20:20:16,026 - INFO - ✓ Created workflow for balanced scenario: org_gpt_6_gem_wo_blend50.png
# 2024-11-22 20:20:16,028 - INFO - ✓ Created workflow for me_dominant scenario: org_gpt_6_gem_wo_me80.png
# 2024-11-22 20:20:17,032 - INFO -
# Processing donor 80/84: org_gpt_7_gem_demo
# 2024-11-22 20:20:17,034 - INFO - ✓ Created workflow for random scenario: org_gpt_7_gem_demo_rand50.png
# 2024-11-22 20:20:17,035 - INFO - ✓ Created workflow for donor_dominant scenario: org_gpt_7_gem_demo_donor80.png
# 2024-11-22 20:20:17,037 - INFO - ✓ Created workflow for balanced scenario: org_gpt_7_gem_demo_blend50.png
# 2024-11-22 20:20:17,039 - INFO - ✓ Created workflow for me_dominant scenario: org_gpt_7_gem_demo_me80.png
# 2024-11-22 20:20:17,039 - INFO - Completed 80/84 donors
# 2024-11-22 20:20:18,045 - INFO -
# Processing donor 81/84: org_gpt_7_gem_wo
# 2024-11-22 20:20:18,051 - INFO - ✓ Created workflow for random scenario: org_gpt_7_gem_wo_rand47.png
# 2024-11-22 20:20:18,055 - INFO - ✓ Created workflow for donor_dominant scenario: org_gpt_7_gem_wo_donor80.png
# 2024-11-22 20:20:18,061 - INFO - ✓ Created workflow for balanced scenario: org_gpt_7_gem_wo_blend50.png
# 2024-11-22 20:20:18,063 - INFO - ✓ Created workflow for me_dominant scenario: org_gpt_7_gem_wo_me80.png
# 2024-11-22 20:20:19,069 - INFO -
# Processing donor 82/84: org_gpt_8_gem_demo
# 2024-11-22 20:20:19,076 - INFO - ✓ Created workflow for random scenario: org_gpt_8_gem_demo_rand32.png
# 2024-11-22 20:20:19,079 - INFO - ✓ Created workflow for donor_dominant scenario: org_gpt_8_gem_demo_donor80.png
# 2024-11-22 20:20:19,082 - INFO - ✓ Created workflow for balanced scenario: org_gpt_8_gem_demo_blend50.png
# 2024-11-22 20:20:19,085 - INFO - ✓ Created workflow for me_dominant scenario: org_gpt_8_gem_demo_me80.png
# 2024-11-22 20:20:20,090 - INFO -
# Processing donor 83/84: org_gpt_8_gem_wo
# 2024-11-22 20:20:20,100 - INFO - ✓ Created workflow for random scenario: org_gpt_8_gem_wo_rand28.png
# 2024-11-22 20:20:20,107 - INFO - ✓ Created workflow for donor_dominant scenario: org_gpt_8_gem_wo_donor80.png
# 2024-11-22 20:20:20,114 - INFO - ✓ Created workflow for balanced scenario: org_gpt_8_gem_wo_blend50.png
# 2024-11-22 20:20:20,116 - INFO - ✓ Created workflow for me_dominant scenario: org_gpt_8_gem_wo_me80.png
# 2024-11-22 20:20:21,122 - INFO -
# Processing donor 84/84: org_gpt_9_gem_wo
# 2024-11-22 20:20:21,128 - INFO - ✓ Created workflow for random scenario: org_gpt_9_gem_wo_rand73.png
# 2024-11-22 20:20:21,137 - INFO - ✓ Created workflow for donor_dominant scenario: org_gpt_9_gem_wo_donor80.png
# 2024-11-22 20:20:21,139 - INFO - ✓ Created workflow for balanced scenario: org_gpt_9_gem_wo_blend50.png
# 2024-11-22 20:20:21,142 - INFO - ✓ Created workflow for me_dominant scenario: org_gpt_9_gem_wo_me80.png
# 2024-11-22 20:20:22,147 - INFO - Batch processing completed!

# %%
# Step 4: Check progress
unprocessed = check_progress()

# Expected output: List of unprocessed workflows
# Use this to track progress

# %%
# Helper function to mark workflows as processed
def mark_workflow_complete(workflow_file: str, notes: str = "Generated successfully"):
    """Mark a workflow as completed after running it in ComfyUI.
    Usage: mark_workflow_complete("donor_id_scenario.json")"""
    tracker = WorkflowTracker(PATHS['logs'])
    tracker.mark_processed(workflow_file, notes)
    print(f"Marked {workflow_file} as processed")

# Example usage:
# mark_workflow_complete("aug_cla_4_gem_wo_donor80.json", "Generated successfully")
